# %%
import tweepy
from tweepy import OAuthHandler

consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
# searches = ['16Personalities', 'AnthonyKusuma']
searches = ['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP', 'INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP']

for search in searches:
  print(search)
  for tweet in api.search(q=search, tweet_mode="extended", lang='in'):
    if hasattr(tweet, "retweeted_status"):
      continue
    else:
      print(tweet.id_str, tweet.user.screen_name)
      print(tweet.full_text)
      print('------------------------------------------------------------------------')
# Out:
# ENFJ
# 1354251550667886592 wirapradips
# @sastradyaksa Hi, Sas! MBTI gua ENFJ bisa dibilang itu ngga pernah berubah dari pertama kali ngetest sampe sekarang, terus shio ayam sedangkan zodiak capri. Relatenya itu karena capri kan keras kepala, sedangkan gua lumayan keras kepala anaknya dan a lil bit ambitious.
# ------------------------------------------------------------------------
# 1354230964998688770 sungjinbaba
# @helloarasan jackson ENFJ? sama kaya sungjin bangchan berati? baruu tauuuu😭
# ------------------------------------------------------------------------
# 1354221221550800900 helloarasan
# *pas banget pake wajah Jackson 😂 pas bangettt soalnya Jackson kan ENFJ (juga) 😍 https://t.co/BjK5j5TaSP
# ------------------------------------------------------------------------
# 1354200822716878849 grifcutz
# @cececals enfj, gemini☀️ taurus🌜
# ------------------------------------------------------------------------
# 1354152247983099905 Ben_Martin2
# ...
